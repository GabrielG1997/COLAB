# %% [markdown]
# <a href="https://colab.research.google.com/github/GabrielG1997/COLAB/blob/main/matplotlib_lib_exercise_0_DIO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib
import matplotlib.pyplot as plot
from sklearn.datasets import make_regression

# %%
x,y = make_regression(n_samples = 200, n_features=1, noise = 30)

# %%
plot.scatter(x,y)
plot.show()
